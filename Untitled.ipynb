# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.random.randn(10000)
b = np.random.randn(10000, 10)

# %%
plt.hist(b.sum(axis=-1));
plt.hist(a);

# %%
'fjeiwajfoie_'.format(**locals())
# Out:
# 'fjeiwajfoie_'
