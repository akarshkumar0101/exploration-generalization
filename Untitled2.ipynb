# %%
! hostname
! whoami
! pwd
# Out:
# dhcp-10-29-106-120.dyn.MIT.EDU
# akarshkumar0101
# /Users/akarshkumar0101/exploration-generalization

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %run imports.py

# %%
env = make_env('miner', 'ext', 128, 0, 0, 'easy', gamma=0.999, latent_keys=[], device='cpu', cov=False, actions='ordinal')
print(env.action_meanings)
# Out:
# ['left', 'down', 'noop', 'up', 'right']

# %%
# %%time
obs, info = env.reset()
x, y = [obs], []
for i in tqdm(range(256)):
    action = env.action_space.sample()
    obs, rew, done, info = env.step(action)
    x.append(obs)
    y.append(action)
# Out:
#   0%|          | 0/256 [00:00<?, ?it/s]
# CPU times: user 608 ms, sys: 60.9 ms, total: 669 ms
# Wall time: 217 ms

# %%
x = np.stack(x)
y = np.stack(y)

# %%
y.shape
# Out:
# (1000, 102)

# %%
def get_batch(batch_size=128):
    env = make_env("miner", "ext", 128, 0, 0, "easy", gamma=0.999, latent_keys=[], device="cpu", cov=False, actions="ordinal")
    obs, info = env.reset()
    x, y = [obs], []
    for i in range(256):
        action = env.action_space.sample()
        obs, rew, done, info = env.step(action)
        x.append(obs)
        y.append(action)
    x = np.stack(x)
    y = np.stack(y)

    n_steps, n_envs = y.shape
    i_step, i_env = np.random.randint(0, n_steps, size=batch_size), np.arange(batch_size) % n_envs
    obs_now, obs_nxt, act_now = x[i_step, i_env], x[i_step + 1, i_env], y[i_step, i_env]
    return obs_now, obs_nxt, act_now

# %%
# %%time
obs_now, obs_nxt, act_now = get_batch(2048)
obs_now.shape, obs_nxt.shape, act_now.shape
# Out:
# building procgen...done
# CPU times: user 1.4 s, sys: 275 ms, total: 1.67 s
# Wall time: 2.29 s
# ((2048, 64, 64, 3), (2048, 64, 64, 3), (2048,))

# %%
net = nn.Sequential(*[
    nn.Conv2d(6, 32, 3, padding=1),
    nn.ReLU(),
    
    nn.Conv2d(32, 32, 3, padding=1),
    nn.ReLU(),
    nn.Conv2d(32, 32, 3, padding=1),
    nn.ReLU(),
    nn.MaxPool2d(3),
    
    nn.Conv2d(32, 32, 3, padding=1),
    nn.ReLU(),
    nn.Conv2d(32, 32, 3, padding=1),
    nn.ReLU(),
    nn.MaxPool2d(3),
    
    nn.Conv2d(32, 32, 3, padding=1),
    nn.ReLU(),
    nn.Conv2d(32, 32, 3, padding=1),
    nn.ReLU(),
    nn.MaxPool2d(3),
    
    nn.Flatten(),
    
    nn.LazyLinear(128),
    nn.ReLU(),
    nn.LazyLinear(32),
    nn.ReLU(),
    nn.LazyLinear(5),
])


net(torch.randn(1, 6, 64, 64))
# Out:
# tensor([[ 0.1744,  0.1176, -0.0489, -0.0200, -0.1586]],
#        grad_fn=<AddmmBackward0>)

# %%
env = make_env()
env.single_observation_space.shape
# Out:
# (64, 64, 3)

# %%
opt = torch.optim.Adam(net.parameters(), lr=1e-4)

for i in range(100):
    
    opt.zero_grad()
    loss.backward()
    opt.step()

# %%
x.shape
# Out:
# (257, 128, 64, 64, 3)

# %%
257*128
# Out:
# 32896

# %%
obs_now, obs_nxt, act_now = get_batch(128)

# %%
1000*1024*64*64*3/1e9
# Out:
# 12.582912

# %%
del net, get_batch

# %%
from test_e3b_idm2 import *

# %%
device = 'mps'

# %%
def plot_grad(net):
    gs = []
    for neti in net:
        if len(list(neti.parameters()))>1:
            g = torch.cat([p.grad.flatten() for p in neti.parameters()])
            gs.append(g.abs().mean().item())
            
    plt.figure(figsize=(10, 3))
    plt.subplot(121); plt.plot(gs)
    plt.subplot(122); plt.plot(gs)
    plt.yscale('log')

# %%
net = create_net()
net = net.to(device)
opt = torch.optim.Adam(net.parameters(), lr=3e-4)  # , weight_decay=1e-5)

losses = []
pbar = tqdm(range(1000))
for i_batch in pbar:
    obs_now, obs_nxt, act_now = get_batch(2048)

    obs_now = torch.from_numpy(obs_now).to(device)
    obs_nxt = torch.from_numpy(obs_nxt).to(device)
    act_now = torch.from_numpy(act_now).to(device)
    x = torch.cat([obs_now, obs_nxt], dim=-1).permute(0, 3, 1, 2) / 255.0
    logits = net(x)

    ce = torch.nn.functional.cross_entropy(logits, act_now, reduction="none")
    loss = ce.mean()

    opt.zero_grad()
    loss.backward()
    opt.step()

    accuracy = (logits.argmax(dim=-1) == act_now).sum().item() / len(act_now)
    data = dict(loss=loss.item(), accuracy=accuracy, ppl=np.exp(loss.item()))
    losses.append(loss.item())

    keys_tqdm = ["loss", "accuracy", "ppl"]
    pbar.set_postfix({k: data[k] for k in keys_tqdm})
    
    if i_batch%100==0:
        print(loss.item())
        plot_grad(net)
        plt.show()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 1.6112107038497925
# 1.6092214584350586
# 1.6095205545425415
# 1.6093367338180542
# 1.6092422008514404
# 1.3920485973358154
# 0.9403916597366333
# 0.7094513773918152
# 0.6117414236068726
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[143], line 23
#      20 loss.backward()
#      21 opt.step()
# ---> 23 accuracy = (logits.argmax(dim=-1) == act_now).sum().item() / len(act_now)
#      24 data = dict(loss=loss.item(), accuracy=accuracy, ppl=np.exp(loss.item()))
#      25 losses.append(loss.item())
#
# KeyboardInterrupt:

# %%
plt.plot(losses)

# %%
from test_e3b_idm2 import *

# %%
def plot_grad(net):
    gs = []
    for neti in [net.encoder, net.idm]:
        for netii in neti:
            if len(list(netii.parameters()))>1:
                g = torch.cat([p.grad.flatten() for p in netii.parameters()])
                gs.append(g.abs().mean().item())
        if neti==net.encoder:
            start_idm = len(gs)-.5
            
    plt.figure(figsize=(10, 3))
    plt.subplot(121); plt.plot(gs)
    plt.axvline(x=start_idm)
    plt.subplot(122); plt.plot(gs)
    plt.axvline(x=start_idm)
    plt.yscale('log')

# %%
net = IDM()
net(torch.randn(1, 64, 64, 3), torch.randn(1, 64, 64, 3))
# Out:
# tensor([[-0.0286,  0.0223, -0.0544,  0.0570,  0.0146]],
#        grad_fn=<AddmmBackward0>)

# %%
net = IDM()
net = net.to(device)
opt = torch.optim.Adam(net.parameters(), lr=3e-4)  # , weight_decay=1e-5)

losses = []
pbar = tqdm(range(1000))
for i_batch in pbar:
    obs_now, obs_nxt, act_now = get_batch(2048)

    obs_now = torch.from_numpy(obs_now).to(device)
    obs_nxt = torch.from_numpy(obs_nxt).to(device)
    act_now = torch.from_numpy(act_now).to(device)
    logits = net(obs_now, obs_nxt)

    ce = torch.nn.functional.cross_entropy(logits, act_now, reduction="none")
    loss = ce.mean()

    opt.zero_grad()
    loss.backward()
    opt.step()

    accuracy = (logits.argmax(dim=-1) == act_now).sum().item() / len(act_now)
    data = dict(loss=loss.item(), accuracy=accuracy, ppl=np.exp(loss.item()))
    losses.append(loss.item())

    keys_tqdm = ["loss", "accuracy", "ppl"]
    pbar.set_postfix({k: data[k] for k in keys_tqdm})
    
    if i_batch%100==0:
        print(loss.item())
        plot_grad(net)
        plt.show()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 1.6091837882995605
# 1.6092694997787476
# 1.6092021465301514
# 1.6097681522369385
# 1.6092036962509155
# 1.2887203693389893
# 1.0596985816955566
# 0.9342501759529114
# 0.8359629511833191
# 0.736029326915741

# %%
plt.plot(losses)

# %%
net = IDM()
net = net.to(device)
opt = torch.optim.Adam(net.parameters(), lr=3e-4)  # , weight_decay=1e-5)

losses = []
pbar = tqdm(range(1000))
for i_batch in pbar:
    obs_now, obs_nxt, act_now = get_batch(2048)

    obs_now = torch.from_numpy(obs_now).to(device)
    obs_nxt = torch.from_numpy(obs_nxt).to(device)
    act_now = torch.from_numpy(act_now).to(device)
    logits = net(obs_now, obs_nxt)

    ce = torch.nn.functional.cross_entropy(logits, act_now, reduction="none")
    loss = ce.mean()

    opt.zero_grad()
    loss.backward()
    opt.step()

    accuracy = (logits.argmax(dim=-1) == act_now).sum().item() / len(act_now)
    data = dict(loss=loss.item(), accuracy=accuracy, ppl=np.exp(loss.item()))
    losses.append(loss.item())

    keys_tqdm = ["loss", "accuracy", "ppl"]
    pbar.set_postfix({k: data[k] for k in keys_tqdm})
    
    if i_batch%100==0:
        print(loss.item())
        plot_grad(net)
        plt.show()
# Out:
# updated
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 1.611489176750183
# 1.6091982126235962
# 1.2571330070495605
# 1.132684350013733
# 1.057009220123291
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[160], line 8
#       6 pbar = tqdm(range(1000))
#       7 for i_batch in pbar:
# ----> 8     obs_now, obs_nxt, act_now = get_batch(2048)
#      10     obs_now = torch.from_numpy(obs_now).to(device)
#      11     obs_nxt = torch.from_numpy(obs_nxt).to(device)
#
# File ~/exploration-generalization/test_e3b_idm2.py:20, in get_batch(batch_size)
#      18 for i in range(256):
#      19     action = env.action_space.sample()
# ---> 20     obs, rew, done, info = env.step(action)
#      21     x.append(obs)
#      22     y.append(action)
#
# File ~/exploration-generalization/env_procgen.py:136, in OrdinalActions.step(self, action)
#     134 def step(self, action):
#     135     action = self.i_actions[action]
# --> 136     obs, rew, done, info = self.env.step(action)
#     137     return obs, rew, done, info
#
# File ~/miniconda3/lib/python3.10/site-packages/gym/core.py:336, in RewardWrapper.step(self, action)
#     335 def step(self, action):
# --> 336     observation, reward, done, info = self.env.step(action)
#     337     return observation, self.reward(reward), done, info
#
# File ~/miniconda3/lib/python3.10/site-packages/gym/wrappers/normalize.py:93, in NormalizeReward.step(self, action)
#      92 def step(self, action):
# ---> 93     obs, rews, dones, infos = self.env.step(action)
#      94     if not self.is_vector_env:
#      95         rews = np.array([rews])
#
# File ~/exploration-generalization/env_procgen.py:120, in RewardSelector.step(self, action)
#     119 def step(self, action):
# --> 120     obs, rew, done, info = self.env.step(action)
#     121     rew = info[f"rew_{self.obj}"].detach().cpu().numpy()
#     122     return obs, rew, done, info
#
# File ~/exploration-generalization/env_procgen.py:95, in StoreReturns.step(self, action)
#      94 def step(self, action):
# ---> 95     obs, rew, done, info = self.env.step(action)
#      96     self.update_rets(info)
#      97     return obs, rew, done, info
#
# File ~/exploration-generalization/env_procgen.py:252, in ObservationEncoder.step(self, action)
#     251 def step(self, action):
# --> 252     obs, rew, done, info = self.env.step(action)
#     253     self.update_info(info)
#     254     return obs, rew, done, info
#
# File ~/exploration-generalization/env_procgen.py:67, in ToTensor.step(self, action)
#      66 def step(self, action):
# ---> 67     obs, rew, done, info = self.env.step(action)
#      68     info["obs"] = torch.from_numpy(obs).to(self.device)
#      69     info["rew_ext"] = torch.from_numpy(rew).to(self.device)
#
# File ~/exploration-generalization/env_procgen.py:43, in StoreObs.step(self, action)
#      42 def step(self, action):
# ---> 43     obs, rew, done, info = self.env.step(action)
#      44     self.past_obs.append(obs[: self.n_envs])
#      45     self.past_obs = self.past_obs[-self.buf_size :]
#
# File ~/exploration-generalization/env_procgen.py:25, in ProcgenWrapper.step(self, action)
#      24 def step(self, action):
# ---> 25     obs, rew, done, infos = self.env.step(action)
#      26     obs = obs["rgb"]
#      27     return obs, rew, done, {}
#
# File ~/miniconda3/lib/python3.10/site-packages/gym3/interop.py:328, in ToBaselinesVecEnv.step(self, ac)
#     326 def step(self, ac):
#     327     self.step_async(ac)
# --> 328     return self.step_wait()
#
# File ~/miniconda3/lib/python3.10/site-packages/gym3/interop.py:323, in ToBaselinesVecEnv.step_wait(self)
#     322 def step_wait(self):
# --> 323     rew, ob, first = self.env.observe()
#     324     return ob, rew, first, self.env.get_info()
#
# File ~/miniconda3/lib/python3.10/site-packages/gym3/libenv.py:345, in CEnv.observe(self)
#     344 def observe(self) -> Tuple[np.ndarray, Dict[str, np.ndarray], np.ndarray]:
# --> 345     self._c_lib.libenv_observe(self._c_env)
#     346     return (
#     347         self._maybe_copy_ndarray(self._rew),
#     348         self._maybe_copy_dict(self._ob),
#     349         self._maybe_copy_ndarray(self._first),
#     350     )
#
# KeyboardInterrupt:

# %%
# with layernorm element wise = False
plt.plot(losses)

# %%
# with layernorm element wise = True
plt.plot(losses)

# %%
net
# Out:
# IDM(
#   (encoder): Sequential(
#     (0): LayerNorm((3, 64, 64), eps=1e-05, elementwise_affine=False)
#     (1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): ReLU()
#     (3): LayerNorm((32, 64, 64), eps=1e-05, elementwise_affine=False)
#     (4): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): LayerNorm((32, 64, 64), eps=1e-05, elementwise_affine=False)
#     (7): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (10): LayerNorm((32, 21, 21), eps=1e-05, elementwise_affine=False)
#     (11): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): LayerNorm((32, 21, 21), eps=1e-05, elementwise_affine=False)
#     (14): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU()
#     (16): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (17): LayerNorm((32, 7, 7), eps=1e-05, elementwise_affine=False)
#     (18): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): ReLU()
#     (20): LayerNorm((32, 7, 7), eps=1e-05, elementwise_affine=False)
#     (21): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU()
#     (23): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (24): Flatten(start_dim=1, end_dim=-1)
#     (25): LayerNorm((128,), eps=1e-05, elementwise_affine=False)
#     (26): Linear(in_features=128, out_features=64, bias=True)
#     (27): ReLU()
#   )
#   (idm): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=5, bias=True)
#   )
# )

# %%
from test_e3b_idm import *

# %%
device = 'mps'
obs_now, obs_nxt, act_now = get_batch(128, 256, batch_size=128*256)
obs_now = torch.from_numpy(obs_now).to(device)
obs_nxt = torch.from_numpy(obs_nxt).to(device)
act_now = torch.from_numpy(act_now).to(device)

minxy = MinerXYEncoder()

# %%
obs_now.shape, obs_nxt.shape, act_now.shape
# Out:
# (torch.Size([32768, 64, 64, 3]),
#  torch.Size([32768, 64, 64, 3]),
#  torch.Size([32768]))

# %%
xy_now = minxy.encode(obs_now)
xy_nxt = minxy.encode(obs_nxt)

# %%
obs_noop = (xy_now==xy_nxt).all(dim=-1)
act_noop = act_now==2

# %%
(obs_noop==act_noop).sum()/len(act_noop)
# Out:
# tensor(0.8356, device='mps:0')

# %%
2^(log((100-X)% * 1 + X% * 1/4))
2^(log((100-X)% * 1 + X% * 1/4))

# %%
np.exp(-np.log(.835*1+0.165*1/4))
# Out:
# 1.1412268188302426
